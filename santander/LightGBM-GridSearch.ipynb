# %% [markdown]
# ### MinMaxScaling X and y

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
train = pd.read_csv('data/train.csv', index_col=0)

X = train.drop('target', axis=1)
y = train.target
y_log = np.log1p(y)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y_log, test_size=0.1, random_state=42
)

# %%
from sklearn.metrics import make_scorer

def rmsle_metric(y_test, y_pred) : 
    assert len(y_test) == len(y_pred)
    y_test = np.exp(y_test)-1
    y_pred = np.exp(y_pred)-1
    rmsle = np.sqrt(np.mean((np.log(1+y_pred) - np.log(1+y_test))**2))
    return ('RMSLE', rmsle, False)

grid_scorer = make_scorer(lambda y_test, y_pred: rmsle_metric(y_test, y_pred)[1], greater_is_better=False)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.decomposition import PCA, NMF
from sklearn.feature_selection import SelectKBest, mutual_info_regression


pipe = Pipeline([
    ('reduce_dim', PCA()),
    ('regressor', lgb.LGBMRegressor(
        objective='regression',
        num_leaves=31,
        learning_rate=0.01,
        silent=False
    ))
])

N_FEATURES_OPTIONS = [50, 100, 300]

param_grid = [
    {
        'reduce_dim': [PCA(iterated_power=7), NMF()],
        'reduce_dim__n_components': N_FEATURES_OPTIONS,
        'regressor__boosting_type': ['gbdt', 'dart'], #'goss', 'rf'],
        'regressor__n_estimators': [50, 100, 500]
    },
    {
        'reduce_dim': [SelectKBest(mutual_info_regression)],
        'reduce_dim__k': N_FEATURES_OPTIONS,
        'regressor__boosting_type': ['gbdt', 'dart'], #'goss', 'rf'],
        'regressor__n_estimators': [50, 100, 500]
    },
]
reducer_labels = ['PCA', 'NMF', 'KBest']

grid = GridSearchCV(pipe, cv=5, n_jobs=1, param_grid=param_grid) #, scoring=grid_scorer)
grid.fit(X_train, y_train) #, **{
    #'regressor__eval_set':[(X_test, y_test)],
    #'regressor__eval_metric':rmsle_metric,
    #'regressor__early_stopping_rounds':100
    #}
#)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('reduce_dim', PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('regressor', LGBMRegressor(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#        learning_rate=0.01, max_depth=-1, min_child_samples=20,
#   ...0, reg_lambda=0.0, silent=False, subsample=1.0,
#        subsample_for_bin=200000, subsample_freq=0))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid=[{'reduce_dim': [PCA(copy=True, iterated_power=7, n_components=300, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False), NMF(alpha=0.0, beta_loss='frobenius', init=None, l1_ratio=0.0, max_iter=200,
#   n_components=300, random_state=None, shuffle=False, solver='cd',
#   tol=0.0001,...100, 300], 'regressor__boosting_type': ['gbdt', 'dart'], 'regressor__n_estimators': [50, 100, 500]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
y_pred = grid.predict(X_test)
rmsle_metric(y_test, y_pred)
# Out:
# ('RMSLE', 1.42029471280403, False)

# %%
from sklearn.externals import joblib

joblib.dump(grid.best_estimator_, 'LightGBM-GridSearch-1_420.pkl')
# Out:
# ['LightGBM-GridSearch-1_420.pkl']

# %%
grid.cv_results_.keys()
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_reduce_dim', 'param_reduce_dim__n_components', 'param_regressor__boosting_type', 'param_regressor__n_estimators', 'param_reduce_dim__k', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'split3_test_score', 'split4_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score', 'split0_train_score', 'split1_train_score', 'split2_train_score', 'split3_train_score', 'split4_train_score', 'mean_train_score', 'std_train_score'])

# %%
keys = ['param_reduce_dim', 'param_reduce_dim__n_components', 'param_regressor__boosting_type', 'param_regressor__n_estimators', 'param_reduce_dim__k', 'params',
       'mean_test_score', 'std_test_score', 'rank_test_score','mean_train_score', 'std_train_score']

results = pd.DataFrame(grid.cv_results_)[keys]
# Out:
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/deprecation.py:122: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)

# %%
results.sort_values('mean_test_score')
# Out:
#                                      param_reduce_dim  \
# 10  PCA(copy=True, iterated_power=7, n_components=...
# 4   PCA(copy=True, iterated_power=7, n_components=...
# 16  PCA(copy=True, iterated_power=7, n_components=...
# 34  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 22  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 28  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 52  SelectKBest(k=300,\n      score_func=<function...
# 40  SelectKBest(k=300,\n      score_func=<function...
# 46  SelectKBest(k=300,\n      score_func=<function...
# 17  PCA(copy=True, iterated_power=7, n_components=...
# 11  PCA(copy=True, iterated_power=7, n_components=...
# 5   PCA(copy=True, iterated_power=7, n_components=...
# 35  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 23  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 29  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 53  SelectKBest(k=300,\n      score_func=<function...
# 41  SelectKBest(k=300,\n      score_func=<function...
# 47  SelectKBest(k=300,\n      score_func=<function...
# 33  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 27  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 15  PCA(copy=True, iterated_power=7, n_components=...
# 3   PCA(copy=True, iterated_power=7, n_components=...
# 9   PCA(copy=True, iterated_power=7, n_components=...
# 21  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 51  SelectKBest(k=300,\n      score_func=<function...
# 39  SelectKBest(k=300,\n      score_func=<function...
# 45  SelectKBest(k=300,\n      score_func=<function...
# 30  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 24  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 12  PCA(copy=True, iterated_power=7, n_components=...
# 18  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 0   PCA(copy=True, iterated_power=7, n_components=...
# 6   PCA(copy=True, iterated_power=7, n_components=...
# 31  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 42  SelectKBest(k=300,\n      score_func=<function...
# 48  SelectKBest(k=300,\n      score_func=<function...
# 36  SelectKBest(k=300,\n      score_func=<function...
# 25  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 1   PCA(copy=True, iterated_power=7, n_components=...
# 7   PCA(copy=True, iterated_power=7, n_components=...
# 13  PCA(copy=True, iterated_power=7, n_components=...
# 19  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 43  SelectKBest(k=300,\n      score_func=<function...
# 37  SelectKBest(k=300,\n      score_func=<function...
# 32  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 20  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 8   PCA(copy=True, iterated_power=7, n_components=...
# 26  NMF(alpha=0.0, beta_loss='frobenius', init=Non...
# 49  SelectKBest(k=300,\n      score_func=<function...
# 2   PCA(copy=True, iterated_power=7, n_components=...
# 14  PCA(copy=True, iterated_power=7, n_components=...
# 38  SelectKBest(k=300,\n      score_func=<function...
# 44  SelectKBest(k=300,\n      score_func=<function...
# 50  SelectKBest(k=300,\n      score_func=<function...
#
#    param_reduce_dim__n_components param_regressor__boosting_type  \
# 10                            100                           dart
# 4                              50                           dart
# 16                            300                           dart
# 34                            300                           dart
# 22                             50                           dart
# 28                            100                           dart
# 52                            NaN                           dart
# 40                            NaN                           dart
# 46                            NaN                           dart
# 17                            300                           dart
# 11                            100                           dart
# 5                              50                           dart
# 35                            300                           dart
# 23                             50                           dart
# 29                            100                           dart
# 53                            NaN                           dart
# 41                            NaN                           dart
# 47                            NaN                           dart
# 33                            300                           dart
# 27                            100                           dart
# 15                            300                           dart
# 3                              50                           dart
# 9                             100                           dart
# 21                             50                           dart
# 51                            NaN                           dart
# 39                            NaN                           dart
# 45                            NaN                           dart
# 30                            300                           gbdt
# 24                            100                           gbdt
# 12                            300                           gbdt
# 18                             50                           gbdt
# 0                              50                           gbdt
# 6                             100                           gbdt
# 31                            300                           gbdt
# 42                            NaN                           gbdt
# 48                            NaN                           gbdt
# 36                            NaN                           gbdt
# 25                            100                           gbdt
# 1                              50                           gbdt
# 7                             100                           gbdt
# 13                            300                           gbdt
# 19                             50                           gbdt
# 43                            NaN                           gbdt
# 37                            NaN                           gbdt
# 32                            300                           gbdt
# 20                             50                           gbdt
# 8                             100                           gbdt
# 26                            100                           gbdt
# 49                            NaN                           gbdt
# 2                              50                           gbdt
# 14                            300                           gbdt
# 38                            NaN                           gbdt
# 44                            NaN                           gbdt
# 50                            NaN                           gbdt
#
#    param_regressor__n_estimators param_reduce_dim__k  \
# 10                           100                 NaN
# 4                            100                 NaN
# 16                           100                 NaN
# 34                           100                 NaN
# 22                           100                 NaN
# 28                           100                 NaN
# 52                           100                 300
# 40                           100                  50
# 46                           100                 100
# 17                           500                 NaN
# 11                           500                 NaN
# 5                            500                 NaN
# 35                           500                 NaN
# 23                           500                 NaN
# 29                           500                 NaN
# 53                           500                 300
# 41                           500                  50
# 47                           500                 100
# 33                            50                 NaN
# 27                            50                 NaN
# 15                            50                 NaN
# 3                             50                 NaN
# 9                             50                 NaN
# 21                            50                 NaN
# 51                            50                 300
# 39                            50                  50
# 45                            50                 100
# 30                            50                 NaN
# 24                            50                 NaN
# 12                            50                 NaN
# 18                            50                 NaN
# 0                             50                 NaN
# 6                             50                 NaN
# 31                           100                 NaN
# 42                            50                 100
# 48                            50                 300
# 36                            50                  50
# 25                           100                 NaN
# 1                            100                 NaN
# 7                            100                 NaN
# 13                           100                 NaN
# 19                           100                 NaN
# 43                           100                 100
# 37                           100                  50
# 32                           500                 NaN
# 20                           500                 NaN
# 8                            500                 NaN
# 26                           500                 NaN
# 49                           100                 300
# 2                            500                 NaN
# 14                           500                 NaN
# 38                           500                  50
# 44                           500                 100
# 50                           500                 300
#
#                                                params  mean_test_score  \
# 10  {'reduce_dim': PCA(copy=True, iterated_power=7...        -9.467996
# 4   {'reduce_dim': PCA(copy=True, iterated_power=7...        -9.467711
# 16  {'reduce_dim': PCA(copy=True, iterated_power=7...        -9.461246
# 34  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -9.452988
# 22  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -9.446313
# 28  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -9.445717
# 52  {'reduce_dim': SelectKBest(k=300,
#       score_...        -9.440786
# 40  {'reduce_dim': SelectKBest(k=300,
#       score_...        -9.440202
# 46  {'reduce_dim': SelectKBest(k=300,
#       score_...        -9.439586
# 17  {'reduce_dim': PCA(copy=True, iterated_power=7...        -3.201106
# 11  {'reduce_dim': PCA(copy=True, iterated_power=7...        -3.196150
# 5   {'reduce_dim': PCA(copy=True, iterated_power=7...        -3.188824
# 35  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -3.177341
# 23  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -3.160924
# 29  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -3.159225
# 53  {'reduce_dim': SelectKBest(k=300,
#       score_...        -3.126661
# 41  {'reduce_dim': SelectKBest(k=300,
#       score_...        -3.125116
# 47  {'reduce_dim': SelectKBest(k=300,
#       score_...        -3.123119
# 33  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -0.926420
# 27  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -0.919134
# 15  {'reduce_dim': PCA(copy=True, iterated_power=7...        -0.917048
# 3   {'reduce_dim': PCA(copy=True, iterated_power=7...        -0.913791
# 9   {'reduce_dim': PCA(copy=True, iterated_power=7...        -0.912150
# 21  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...        -0.905695
# 51  {'reduce_dim': SelectKBest(k=300,
#       score_...        -0.897684
# 39  {'reduce_dim': SelectKBest(k=300,
#       score_...        -0.897079
# 45  {'reduce_dim': SelectKBest(k=300,
#       score_...        -0.896713
# 30  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.109083
# 24  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.126527
# 12  {'reduce_dim': PCA(copy=True, iterated_power=7...         0.131655
# 18  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.136077
# 0   {'reduce_dim': PCA(copy=True, iterated_power=7...         0.136437
# 6   {'reduce_dim': PCA(copy=True, iterated_power=7...         0.140201
# 31  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.152018
# 42  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.159357
# 48  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.159842
# 36  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.160891
# 25  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.175747
# 1   {'reduce_dim': PCA(copy=True, iterated_power=7...         0.187956
# 7   {'reduce_dim': PCA(copy=True, iterated_power=7...         0.188606
# 13  {'reduce_dim': PCA(copy=True, iterated_power=7...         0.189519
# 19  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.190674
# 43  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.238792
# 37  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.239198
# 32  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.239311
# 20  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.241632
# 8   {'reduce_dim': PCA(copy=True, iterated_power=7...         0.243468
# 26  {'reduce_dim': NMF(alpha=0.0, beta_loss='frobe...         0.243673
# 49  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.244157
# 2   {'reduce_dim': PCA(copy=True, iterated_power=7...         0.244837
# 14  {'reduce_dim': PCA(copy=True, iterated_power=7...         0.248485
# 38  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.319139
# 44  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.322096
# 50  {'reduce_dim': SelectKBest(k=300,
#       score_...         0.332536
#
#     std_test_score  rank_test_score  mean_train_score  std_train_score
# 10        0.421092               54         -9.365244         0.103102
# 4         0.436715               53         -9.375530         0.103566
# 16        0.427381               52         -9.354178         0.102504
# 34        0.412115               51         -9.402141         0.102598
# 22        0.415810               50         -9.391625         0.106885
# 28        0.411241               49         -9.396379         0.106739
# 52        0.435784               48         -9.361353         0.100158
# 40        0.435080               47         -9.368681         0.100942
# 46        0.436684               46         -9.366672         0.101006
# 17        0.170720               45         -2.910553         0.037857
# 11        0.167092               44         -2.947096         0.039936
# 5         0.173750               43         -2.980821         0.039341
# 35        0.174345               42         -2.997494         0.037636
# 23        0.158103               41         -3.015264         0.040335
# 29        0.181771               40         -3.007369         0.036648
# 53        0.174886               39         -2.942320         0.037420
# 41        0.172359               38         -2.974224         0.036685
# 47        0.171078               37         -2.964487         0.036467
# 33        0.057615               36         -0.885159         0.012464
# 27        0.059931               35         -0.877922         0.012286
# 15        0.061762               34         -0.850129         0.013251
# 3         0.066612               33         -0.863637         0.012365
# 9         0.062760               32         -0.856881         0.012720
# 21        0.055377               31         -0.874874         0.015405
# 51        0.059189               30         -0.852970         0.010021
# 39        0.060158               29         -0.858278         0.010365
# 45        0.060802               28         -0.857075         0.010684
# 30        0.004026               27          0.175959         0.003253
# 24        0.002416               26          0.181774         0.003034
# 12        0.007668               25          0.227422         0.002791
# 18        0.006520               24          0.186677         0.007092
# 0         0.006268               23          0.204326         0.004452
# 6         0.006582               22          0.215649         0.005208
# 31        0.012270               21          0.285929         0.003845
# 42        0.004816               20          0.214687         0.003148
# 48        0.006995               19          0.221348         0.001098
# 36        0.006226               18          0.212584         0.003812
# 25        0.009965               17          0.288614         0.005291
# 1         0.009512               16          0.317834         0.004852
# 7         0.008826               15          0.339562         0.005006
# 13        0.009442               14          0.361609         0.004833
# 19        0.010587               13          0.288673         0.008612
# 43        0.009047               12          0.334265         0.005177
# 37        0.008176               11          0.330589         0.004807
# 32        0.008368               10          0.647502         0.002382
# 20        0.018033                9          0.596309         0.005920
# 8         0.016956                8          0.706493         0.005505
# 26        0.019657                7          0.615657         0.004946
# 49        0.006899                6          0.349536         0.002894
# 2         0.018651                5          0.648685         0.005061
# 14        0.013698                4          0.771933         0.003155
# 38        0.020507                3          0.597431         0.007269
# 44        0.015382                2          0.609949         0.008778
# 50        0.023405                1          0.651273         0.007511

# %%
grid.best_index_
# Out:
# 50

# %%
grid.best_score_
# Out:
# 0.3325356411995954

# %%
results[results['rank_test_score']==3]['params'].values[0]
# Out:
# {'reduce_dim': SelectKBest(k=100,
#        score_func=<function mutual_info_regression at 0x7f7b847aa6a8>),
#  'reduce_dim__k': 50,
#  'regressor__boosting_type': 'gbdt',
#  'regressor__n_estimators': 500}

# %%
del pipe2
pipe2 = Pipeline([
    ('reduce_dim', SelectKBest(k=50)),
    ('regressor', lgb.LGBMRegressor(
        objective='regression',
        num_leaves=31,
        learning_rate=0.01,
        n_estimators=500,
        boosting_type='gbdt'
    ))
])
pipe2.fit(X_train, y_train)
# Out:
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:113: UserWarning: Features [  26   33   36   57   68  121  130  147  177  179  181  218  223  231
#   259  276  294  298  301  321  322  330  333  339  341  349  357  360
#   364  379  386  405  433  443  448  452  463  470  471  485  503  505
#   509  515  516  520  523  527  528  531  556  563  565  579  580  581
#   589  600  611  637  654  664  676  679  682  699  701  710  721  751
#   773  788  793  805  806  807  810  814  845  888  899  910  919  936
#   980 1000 1008 1025 1039 1043 1060 1063 1072 1084 1112 1154 1157 1164
#  1177 1212 1231 1232 1247 1249 1251 1252 1258 1264 1265 1268 1278 1281
#  1287 1294 1295 1298 1324 1328 1400 1416 1454 1457 1459 1464 1475 1495
#  1505 1510 1518 1552 1555 1559 1583 1590 1600 1601 1626 1636 1645 1664
#  1671 1677 1687 1691 1706 1735 1736 1737 1739 1752 1760 1762 1780 1786
#  1830 1841 1842 1851 1863 1875 1903 1906 1917 1926 1945 1964 1969 1994
#  1997 2016 2032 2035 2038 2058 2091 2122 2124 2136 2144 2179 2182 2188
#  2191 2222 2227 2251 2254 2285 2287 2291 2293 2300 2327 2344 2347 2356
#  2367 2368 2389 2395 2427 2439 2443 2447 2457 2478 2484 2494 2504 2505
#  2545 2553 2559 2571 2580 2584 2585 2589 2597 2601 2620 2640 2641 2648
#  2672 2681 2686 2688 2690 2710 2723 2737 2746 2761 2762 2767 2783 2796
#  2804 2807 2811 2814 2818 2819 2827 2861 2867 2890 2892 2905 2906 2911
#  2919 2935 2944 2953 2962 3002 3019 3038 3065 3077 3104 3122 3128 3138
#  3152 3155 3162 3188 3215 3218 3219 3220 3266 3277 3288 3294 3301 3304
#  3319 3320 3335 3336 3340 3353 3361 3366 3370 3379 3393 3402 3442 3466
#  3500 3540 3542 3543 3547 3548 3559 3561 3583 3607 3614 3615 3633 3634
#  3635 3638 3642 3665 3667 3695 3707 3725 3726 3760 3780 3790 3802 3803
#  3804 3810 3811 3812 3814 3838 3840 3851 3898 3901 3907 3919 3931 3941
#  3947 3953 3954 3956 3963 3964 3985 3986 3988 3997 4032 4058 4094 4099
#  4104 4161 4164 4165 4172 4190 4194 4196 4212 4227 4232 4270 4272 4273
#  4278 4308 4318 4321 4341 4353 4370 4374 4382 4395 4430 4433 4448 4456
#  4457 4464 4472 4501 4508 4516 4518 4537 4612 4626 4636 4637 4652 4675
#  4680 4694 4704 4714 4717 4723 4725 4732 4737 4739 4752 4756 4771 4784
#  4807 4820 4834 4847 4858 4860 4880 4890 4901 4904 4915 4923 4929 4931
#  4955 4965 4972 4985] are constant.
#   UserWarning)
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:114: RuntimeWarning: divide by zero encountered in true_divide
#   f = msb / msw
# /home/rafael/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/feature_selection/univariate_selection.py:114: RuntimeWarning: invalid value encountered in true_divide
#   f = msb / msw
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# <ipython-input-52-14b0c5c3753d> in <module>()
#      10     ))
#      11 ])
# ---> 12 pipe2.fit(X_train, y_train)
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     248         Xt, fit_params = self._fit(X, y, **fit_params)
#     249         if self._final_estimator is not None:
# --> 250             self._final_estimator.fit(Xt, y, **fit_params)
#     251         return self
#     252
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     632                                        verbose=verbose, feature_name=feature_name,
#     633                                        categorical_feature=categorical_feature,
# --> 634                                        callbacks=callbacks)
#     635         return self
#     636
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/sklearn.py in fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks)
#     472                               verbose_eval=verbose, feature_name=feature_name,
#     473                               categorical_feature=categorical_feature,
# --> 474                               callbacks=callbacks)
#     475
#     476         if evals_result:
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/engine.py in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     181     # construct booster
#     182     try:
# --> 183         booster = Booster(params=params, train_set=train_set)
#     184         if is_valid_contain_train:
#     185             booster.set_train_data_name(train_data_name)
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/basic.py in __init__(self, params, train_set, model_file, silent)
#    1305             self.handle = ctypes.c_void_p()
#    1306             _safe_call(_LIB.LGBM_BoosterCreate(
# -> 1307                 train_set.construct().handle,
#    1308                 c_str(params_str),
#    1309                 ctypes.byref(self.handle)))
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/basic.py in construct(self)
#     858                                 weight=self.weight, group=self.group, init_score=self.init_score,
#     859                                 predictor=self._predictor, silent=self.silent, feature_name=self.feature_name,
# --> 860                                 categorical_feature=self.categorical_feature, params=self.params)
#     861             if self.free_raw_data:
#     862                 self.data = None
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/basic.py in _lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#     712             self.__init_from_csc(data, params_str, ref_dataset)
#     713         elif isinstance(data, np.ndarray):
# --> 714             self.__init_from_np2d(data, params_str, ref_dataset)
#     715         else:
#     716             try:
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/basic.py in __init_from_np2d(self, mat, params_str, ref_dataset)
#     774             c_str(params_str),
#     775             ref_dataset,
# --> 776             ctypes.byref(self.handle)))
#     777
#     778     def __init_from_csr(self, csr, params_str, ref_dataset):
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/basic.py in _safe_call(ret)
#      47     """
#      48     if ret != 0:
# ---> 49         raise LightGBMError(decode_string(_LIB.LGBM_GetLastError()))
#      50
#      51
#
# LightGBMError: Cannot construct Dataset since there are not useful features.
# It should be at least two unique rows.
# If the num_row (num_data) is small, you can set min_data=1 and min_data_in_bin=1 to fix this.
# Otherwise please make sure you are using the right dataset

# %%
y_pred = pipe2.predict(X_test)
rmsle_metric(y_test, y_pred)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-53-671614b8aa3f> in <module>()
# ----> 1 y_pred = pipe2.predict(X_test)
#       2 rmsle_metric(y_test, y_pred)
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/utils/metaestimators.py in <lambda>(*args, **kwargs)
#     113
#     114         # lambda, but not partial, allows help() to work with update_wrapper
# --> 115         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     116         # update the docstring of the returned function
#     117         update_wrapper(out, self.fn)
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/sklearn/pipeline.py in predict(self, X)
#     305             if transform is not None:
#     306                 Xt = transform.transform(Xt)
# --> 307         return self.steps[-1][-1].predict(Xt)
#     308
#     309     @if_delegate_has_method(delegate='_final_estimator')
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/sklearn.py in predict(self, X, raw_score, num_iteration, pred_leaf, pred_contrib, **kwargs)
#     525                              "input n_features is %s "
#     526                              % (self._n_features, n_features))
# --> 527         return self.booster_.predict(X, raw_score=raw_score, num_iteration=num_iteration,
#     528                                      pred_leaf=pred_leaf, pred_contrib=pred_contrib, **kwargs)
#     529
#
# ~/.virtualenvs/kaggle-santander/lib/python3.6/site-packages/lightgbm/sklearn.py in booster_(self)
#     590         """Get the underlying lightgbm Booster of this model."""
#     591         if self._Booster is None:
# --> 592             raise LGBMNotFittedError('No booster found. Need to call fit beforehand.')
#     593         return self._Booster
#     594
#
# NotFittedError: No booster found. Need to call fit beforehand.
